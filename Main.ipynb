# %%
import numpy
import spacy

nlp = spacy.load("en_core_web_sm")
def merge_currency(doc):
    """
    Merge currency symbols like $ with adjacent numbers into a single token.
    """
    with doc.retokenize() as retokenizer:
        spans = []
        for i, token in enumerate(doc[:-1]):  # Avoid index out of bounds
            if token.text in ["$", "€", "£"] and doc[i + 1].like_num:
                span = doc[token.i : token.i + 2]  # Create span for "$ 20,000"
                spans.append(span)
        for span in spans:
            retokenizer.merge(span)
            
def extract_price_range_dynamic(user_input):
    doc = nlp(user_input)
    merge_currency(doc)

    price_range = {"MinPrice": None, "MaxPrice": None}

    def parse_number(text):
        try:
            text = text.lower().replace("k", "000").replace("$", "").replace(",", "").replace(" ", "").strip("?.!")
            return float(text)
        except ValueError:
            return None

    lower_bound = None
    upper_bound = None
    in_range = False
    single_number_encountered = False  # Flag for single numbers without context

    for token in doc:
        value = parse_number(token.text)

        # Handle range keywords like "between"
        if token.text.lower() == "between":
            in_range = True
            continue

        if value is not None:  # Numeric token
            # Check immediate head and ancestors
            head = token.head.text.lower()
            ancestors = [ancestor.text.lower() for ancestor in token.ancestors]
            children = [child.text.lower() for child in token.children]  # Include children for better context

            # Handle "more than", "less than" by looking at ancestors and children
            if ("more" in ancestors or "above" in ancestors or "over" in ancestors) and "than" in ancestors:
                lower_bound = value
            elif ("less" in ancestors or "below" in ancestors or "under" in ancestors) and "than" in ancestors:
                upper_bound = value

            # Handle explicit range
            elif in_range:
                if lower_bound is None:
                    lower_bound = value
                else:
                    upper_bound = value
                    in_range = False

            # Handle standalone comparison keywords
            elif head in ["under", "below", "less"]:
                upper_bound = value
            elif head in ["over", "above", "more"]:
                lower_bound = value

            # Handle ranges connected by "to", "and"
            elif token.text in ["to", "and"]:
                if lower_bound is None:
                    lower_bound = value
                else:
                    upper_bound = value

            # Default catch for exact values
            elif head in ["for", "within", "around"]:
                upper_bound = value

            # If no context is found, treat the number as an upper bound by default
            else:
                single_number_encountered = True
                upper_bound = value

        # Handle qualitative terms like "cheap" or "luxury"
        elif token.lemma_ in ["cheap", "affordable"]:
            upper_bound = 20000
        elif token.lemma_ in ["luxury", "expensive"]:
            lower_bound = 50000

    # Swap bounds if lower > upper
    if lower_bound and upper_bound and lower_bound > upper_bound:
        lower_bound, upper_bound = upper_bound, lower_bound

    # If a single number was encountered without context, assign it as an upper bound
    if single_number_encountered and lower_bound is None and upper_bound is None:
        upper_bound = value

    price_range["MinPrice"] = lower_bound
    price_range["MaxPrice"] = upper_bound
    return price_range

# %%
def extract_colors(user_input):
    # List of unique colors
    UNIQUE_COLORS = ['White', 'Gray', 'Black', 'Silver', 'Red', 'Blue', 
                     'Green', 'Gold', 'Copper', 'Brown', 'Orange', 'Tan', 
                     'Teal', 'Yellow', 'Maroon']

    # Define darker and lighter color groups
    DARK_COLORS = ['Black', 'Gray', 'Navy', 'Charcoal', 'Brown', 'Maroon', 'Dark Green']
    LIGHT_COLORS = ['White', 'Silver', 'Yellow', 'Beige', 'Light Gray', 'Light Blue', 'Pale Orange']

    # Synonyms for tone-related words
    TONE_MAP = {
        "dark": "dark",
        "light": "light",
        "bright": "light",
        "deep": "dark",
        "pale": "light",
    }

    # Synonyms for colors
    COLOR_SYNONYMS = {
        "grey": "Gray",
        "charcoal": "Black",
        "scarlet": "Red",
        "navy": "Blue",
        "emerald": "Green",
        "golden": "Gold",
        "bronze": "Copper",
        "chocolate": "Brown",
        "amber": "Orange",
        "beige": "Tan",
        "turquoise": "Teal",
        "lemon": "Yellow",
        "burgundy": "Maroon",
    }

    # Reverse mapping for quick lookup
    COLOR_MAP = {color.lower(): color for color in UNIQUE_COLORS}
    for synonym, base_color in COLOR_SYNONYMS.items():
        COLOR_MAP[synonym.lower()] = base_color

    doc = nlp(user_input)
    detected_colors = []
    match_dark = False
    match_light = False
    explicit_color_found = False

    for token in doc:
        token_text = token.text.lower()

        # Check for tone keywords ("dark", "light") with broader context
        if token_text in TONE_MAP:
            tone = TONE_MAP[token_text]
            if tone == "dark":
                match_dark = True
            elif tone == "light":
                match_light = True

        # Check if the token matches any color or synonym
        if token_text in COLOR_MAP:
            base_color = COLOR_MAP[token_text]
            detected_colors.append(base_color)
            explicit_color_found = True

        # Handle tone + color combination (e.g., "dark blue")
        if token_text in TONE_MAP:
            for child in token.children:
                child_text = child.text.lower()
                if child_text in COLOR_MAP:
                    base_color = COLOR_MAP[child_text]
                    detected_colors.append(base_color)
                    explicit_color_found = True

    # If no specific color is mentioned but tone is detected, use dark/light groups
    if not explicit_color_found:
        if match_dark:
            detected_colors.extend(DARK_COLORS)
        if match_light:
            detected_colors.extend(LIGHT_COLORS)

    # Remove duplicates and preserve order
    detected_colors = list(dict.fromkeys(detected_colors))

    return detected_colors

# %%
examples = [
    "I need a pickup truck with 4WD, leather seats, and under 50,000 km.",
    "Do you have a sporty car with a sunroof and under 50,000 km?",
    "Do you have a red convertible under 30,000 km?",
    "Do you have a family SUV with leather seats and low mileage?",
    "Do you have an electric car with a range of at least 300 miles and advanced safety features?",
    "I'm looking for an SUV with captain's chairs and a panoramic sunroof.",
    "Do you have a minivan with stow-and-go seating and rear-seat entertainment?",
    "I'm looking for a high-performance car with launch control and Brembo brakes.",
    "Do you have the car with VIN 1HGCM82633A123456?",
    "I'm looking for the car with VIN 5FNYF6H57LB789012.",
    "Do you have an SUV with off-road capabilities, a roof rack, and skid plates?",
    "Do you have an SUV with remote start, a heated steering wheel, and a power liftgate?",
    "I'm looking for an SUV with third-row seating.",
    "Do you have a hybrid SUV?",
    "I want something fun to drive.",
    "I currently drive a 2018 Toyota Camry. Do you have anything similar?",
    "I'm driving a 2018 Hyundai Tucson right now. Any similar SUVs in stock?",
    "I'm looking for a fun car to drive.",
    "I want an electric car.",
]

for example in examples:
    result = extract_price_range_dynamic(example)
    result2 = extract_colors(example)
    print(f"Input: {example}")
    print(f"Extracted Price Range: {result}")
    print(f"Extracted Color: {result2}")
    print("-" * 50)
# Out:
# Input: I need a pickup truck with 4WD, leather seats, and under 50,000 km.
# Extracted Price Range: {'MinPrice': None, 'MaxPrice': 50000.0}
# Extracted Color: []
# --------------------------------------------------
# Input: Do you have a sporty car with a sunroof and under 50,000 km?
# Extracted Price Range: {'MinPrice': None, 'MaxPrice': 50000.0}
# Extracted Color: []
# --------------------------------------------------
# Input: Do you have a red convertible under 30,000 km?
# Extracted Price Range: {'MinPrice': None, 'MaxPrice': 30000.0}
# Extracted Color: ['Red']
# --------------------------------------------------
# Input: Do you have a family SUV with leather seats and low mileage?
# Extracted Price Range: {'MinPrice': None, 'MaxPrice': None}
# Extracted Color: []
# --------------------------------------------------
# Input: Do you have an electric car with a range of at least 300 miles and advanced safety features?
# Extracted Price Range: {'MinPrice': None, 'MaxPrice': 300.0}
# Extracted Color: []
# --------------------------------------------------
# Input: I'm looking for an SUV with captain's chairs and a panoramic sunroof.
# Extracted Price Range: {'MinPrice': None, 'MaxPrice': None}
# Extracted Color: []
# --------------------------------------------------
# Input: Do you have a minivan with stow-and-go seating and rear-seat entertainment?
# Extracted Price Range: {'MinPrice': None, 'MaxPrice': None}
# Extracted Color: []
# --------------------------------------------------
# Input: I'm looking for a high-performance car with launch control and Brembo brakes.
# Extracted Price Range: {'MinPrice': None, 'MaxPrice': None}
# Extracted Color: []
# --------------------------------------------------
# Input: Do you have the car with VIN 1HGCM82633A123456?
# Extracted Price Range: {'MinPrice': None, 'MaxPrice': None}
# Extracted Color: []
# --------------------------------------------------
# Input: I'm looking for the car with VIN 5FNYF6H57LB789012.
# Extracted Price Range: {'MinPrice': None, 'MaxPrice': None}
# Extracted Color: []
# --------------------------------------------------
# Input: Do you have an SUV with off-road capabilities, a roof rack, and skid plates?
# Extracted Price Range: {'MinPrice': None, 'MaxPrice': None}
# Extracted Color: []
# --------------------------------------------------
# Input: Do you have an SUV with remote start, a heated steering wheel, and a power liftgate?
# Extracted Price Range: {'MinPrice': None, 'MaxPrice': None}
# Extracted Color: []
# --------------------------------------------------
# Input: I'm looking for an SUV with third-row seating.
# Extracted Price Range: {'MinPrice': None, 'MaxPrice': None}
# Extracted Color: []
# --------------------------------------------------
# Input: Do you have a hybrid SUV?
# Extracted Price Range: {'MinPrice': None, 'MaxPrice': None}
# Extracted Color: []
# --------------------------------------------------
# Input: I want something fun to drive.
# Extracted Price Range: {'MinPrice': None, 'MaxPrice': None}
# Extracted Color: []
# --------------------------------------------------
# Input: I currently drive a 2018 Toyota Camry. Do you have anything similar?
# Extracted Price Range: {'MinPrice': None, 'MaxPrice': 2018.0}
# Extracted Color: []
# --------------------------------------------------
# Input: I'm driving a 2018 Hyundai Tucson right now. Any similar SUVs in stock?
# Extracted Price Range: {'MinPrice': None, 'MaxPrice': 2018.0}
# Extracted Color: []
# --------------------------------------------------
# Input: I'm looking for a fun car to drive.
# Extracted Price Range: {'MinPrice': None, 'MaxPrice': None}
# Extracted Color: []
# --------------------------------------------------
# Input: I want an electric car.
# Extracted Price Range: {'MinPrice': None, 'MaxPrice': None}
# Extracted Color: []
# --------------------------------------------------

# %%
# Define the categories
PRICE_CATEGORIES = {
    "$0-$10K": (0, 10000),
    "$10K-$20K": (10000, 20000),
    "$20K-$30K": (20000, 30000),
    "$30K-$50K": (30000, 50000),
    "$50K+": (50000, float("inf"))
}

def map_price_to_category(price_range):
    """
    Maps the extracted price range to predefined price categories.

    Args:
        price_range (dict): The extracted price range with 'MinPrice' and 'MaxPrice'.

    Returns:
        str: The corresponding price category or None if no match is found.
    """
    min_price = price_range["MinPrice"]
    max_price = price_range["MaxPrice"]

    # If there's only a max price, find the category it falls into
    if max_price is not None and min_price is None:
        for category, (low, high) in PRICE_CATEGORIES.items():
            if low <= max_price <= high:
                return category

    # If there's only a min price, find the category it falls into
    if min_price is not None and max_price is None:
        for category, (low, high) in PRICE_CATEGORIES.items():
            if low <= min_price < high:
                return category

    # If both bounds are defined, find a category that fits the range
    if min_price is not None and max_price is not None:
        for category, (low, high) in PRICE_CATEGORIES.items():
            if low >= min_price and high <= max_price:
                return category

        # Special case: if the range spans multiple categories, return the closest upper bound
        for category, (low, high) in PRICE_CATEGORIES.items():
            if low <= min_price <= high or low <= max_price <= high:
                return category

    # If no match is found
    return None

# %%
for example in examples:
    extracted_price_range = extract_price_range_dynamic(example)  # Use your existing price extraction function
    print(f"Input: {example}")
    print(f"Extracted Price Range: {extracted_price_range}")
    print("--------------------------------------------------")
# Out:
# Input: I'm looking for a car under $40,000.
# Extracted Price Range: {'MinPrice': None, 'MaxPrice': 40000.0}
# Price Category: $30K-$50K
# --------------------------------------------------
# Input: Do you have anything between $20,000 and $50,000?
# Extracted Price Range: {'MinPrice': 20000.0, 'MaxPrice': 50000.0}
# Price Category: $20K-$30K
# --------------------------------------------------
# Input: I want an affordable car.
# Extracted Price Range: {'MinPrice': None, 'MaxPrice': 20000}
# Price Category: $10K-$20K
# --------------------------------------------------
# Input: Show me luxury cars over $70,000.
# Extracted Price Range: {'MinPrice': 70000.0, 'MaxPrice': None}
# Price Category: $50K+
# --------------------------------------------------
# Input: Give me a cheap vehicle under $15k.
# Extracted Price Range: {'MinPrice': None, 'MaxPrice': 15000.0}
# Price Category: $10K-$20K
# --------------------------------------------------
# Input: I need a car below $25,000 but above $10,000.
# Extracted Price Range: {'MinPrice': 10000.0, 'MaxPrice': 25000.0}
# Price Category: $10K-$20K
# --------------------------------------------------
# Input: I’m searching for something costing more than 50k.
# Extracted Price Range: {'MinPrice': None, 'MaxPrice': 50000.0}
# Price Category: $30K-$50K
# --------------------------------------------------
# Input: What can I get for less than $30,000?
# Extracted Price Range: {'MinPrice': None, 'MaxPrice': 30000.0}
# Price Category: $20K-$30K
# --------------------------------------------------
# Input: Can I get something for $40,000?
# Extracted Price Range: {'MinPrice': None, 'MaxPrice': 40000.0}
# Price Category: $30K-$50K
# --------------------------------------------------
# Input: Is $20k to $50k within my range?
# Extracted Price Range: {'MinPrice': None, 'MaxPrice': 50000.0}
# Price Category: $30K-$50K
# --------------------------------------------------
# Input: I am looking for a car that costs less than 50000$?
# Extracted Price Range: {'MinPrice': None, 'MaxPrice': 50000.0}
# Price Category: $30K-$50K
# --------------------------------------------------
# Input: My budget is 20,000$
# Extracted Price Range: {'MinPrice': None, 'MaxPrice': 20000.0}
# Price Category: $10K-$20K
# --------------------------------------------------
# Input: I prefer below 15,000
# Extracted Price Range: {'MinPrice': None, 'MaxPrice': 15000.0}
# Price Category: $10K-$20K
# --------------------------------------------------
# Input: Show me cars costing between $25,000 and $30,000.
# Extracted Price Range: {'MinPrice': 25000.0, 'MaxPrice': 30000.0}
# Price Category: $20K-$30K
# --------------------------------------------------
# Input: Cars over $50k and below $100k are my preference.
# Extracted Price Range: {'MinPrice': 50000.0, 'MaxPrice': 100000.0}
# Price Category: $30K-$50K
# --------------------------------------------------

# %%
parsed_criteria = {
    'MinPrice': 20000,               # Extracted minimum price (if provided by NLP)
    'MaxPrice': 50000,               # Extracted maximum price (if provided by NLP)
    'Body': 'Sport Utility',         # Extracted "SUV"
    'Ext_Color_Generic': 'Red'       # Extracted "Red"
}

# %%
import pandas as pd

# --- Step 1: Load the Data ---
df = pd.read_csv('vehicles.csv')

# --- Step 2: Eliminate Unnecessary Columns ---
columns_to_drop = ['MRSP', 'Int_Uphalstery', 'Internet_Price']
df = df.drop(columns=columns_to_drop, errors='ignore')

# --- Step 3: Create Price_Range ---
price_bins = [0, 10000, 20000, 30000, 50000, float('inf')]
price_labels = ['$0-$10K', '$10K-$20K', '$20K-$30K', '$30K-$50K', '$50K+']
df['Price_Range'] = pd.cut(df['SellingPrice'], bins=price_bins, labels=price_labels)

# --- Step 4: Create Miles_Range ---
miles_bins = [0, 10000, 30000, 60000, 100000, float('inf')]
miles_labels = ['0-10K', '10K-30K', '30K-60K', '60K-100K', '100K+']
df['Miles_Range'] = pd.cut(df['Miles'], bins=miles_bins, labels=miles_labels)

# --- Step 5: Drop Rows with Missing Ranges ---
df = df.dropna(subset=['Price_Range', 'Miles_Range'])

# --- Step 6: Define the get_combined_ranges Function ---
def get_combined_ranges(user_min, user_max, bins, labels):
    combined_ranges = []
    for i in range(len(bins) - 1):
        bin_min = bins[i]
        bin_max = bins[i + 1]
        if bin_min >= user_min and bin_max <= user_max:
            combined_ranges.append(labels[i])
    return combined_ranges

# --- Step 7: Define the Ranking Algorithm ---
HIERARCHY_WEIGHTS = {
    'Price_Range': 5,
    'Miles_Range': 4,
    'Body': 4,
    'Fuel_Type': 3,
    'Drivetrain': 3,
    'Make': 3,
    'Year': 3,
    'Transmission': 2,
    'PassengerCapacity': 2,
    'Style_Description': 2,
    'Ext_Color_Generic': 2,
    'InteriorColor': 1
}

def calculate_vehicle_score(vehicle, user_criteria):
    score = 0
    for key, value in user_criteria.items():
        if pd.notna(vehicle.get(key)) and vehicle.get(key) == value:
            score += HIERARCHY_WEIGHTS.get(key, 0)
    return score

def rank_vehicles(df, user_criteria, top_n=10):
    if df.empty:
        return "No matches found. Please update your search criteria."
    df['Score'] = df.apply(lambda row: calculate_vehicle_score(row, user_criteria), axis=1)
    ranked_vehicles = df.sort_values(by='Score', ascending=False)
    return ranked_vehicles.head(top_n)
def filter_vehicles(parsed_criteria):
    """
    Filter vehicles based on parsed NLP criteria.

    Parameters:
        parsed_criteria (dict): User's criteria extracted from NLP input.

    Returns:
        pd.DataFrame or str: Filtered vehicles DataFrame or a message if no matches are found.
    """
    filtered_df = df.copy()

    # Handle price range dynamically
   # min_price = parsed_criteria.get('MinPrice')
   # max_price = parsed_criteria.get('MaxPrice')

    #if min_price is not None or max_price is not None:
        # Apply SellingPrice filters
     #   if min_price is not None:
      #      filtered_df = filtered_df[filtered_df['SellingPrice'] >= min_price]
       # if max_price is not None:
        #    filtered_df = filtered_df[filtered_df['SellingPrice'] <= max_price]

    # Apply other filters based on parsed criteria
    for key, value in parsed_criteria.items():
        print(len(filtered_df))
        #if key not in ['MinPrice', 'MaxPrice']:  # Skip MinPrice and MaxPrice
        if key in filtered_df.columns:
            filtered_df = filtered_df[filtered_df[key] == value]

    return filtered_df


# --- Example NLP Input ---
parsed_criteria = {
    'Price_Range': '$20K-$30K',
    'Ext_Color_Generic': 'Red',
    'Miles_Range': '10K-30K',

}

# Apply filtering
filtered_df = filter_vehicles(parsed_criteria)

# Rank and display results or handle no matches
if isinstance(filtered_df, str) or filtered_df.empty:
    print("No matches found. Please update your search criteria.")
else:
    result = rank_vehicles(filtered_df, parsed_criteria, top_n=10)
    if isinstance(result, str):
        print(result)
    else:
        print(result[['Year', 'Make', 'Model', 'SellingPrice', 'Miles', 'Body', 'Ext_Color_Generic', 'Price_Range', 'Miles_Range', 'Score']])
# Out:
# 1453
# 467
# 46
# 11
# No matches found. Please update your search criteria.

# %%
examples = [
    "I'm looking for a car under $40,000.",
    "Do you have anything between $20,000 and $50,000?",
    "I want an affordable car.",
    "Show me luxury cars over $70,000.",
    "Give me a cheap vehicle under $15k.",
    "I need a car below $25,000 but above $10,000.",
    "I’m searching for something costing more than 50k.",
    "What can I get for less than $30,000?",
    "Can I get something for $40,000?",
    "Is $20k to $50k within my range?",
    "I am looking for a car that costs less than 50000$?",
    "My budget is 20,000$",
    "I prefer below 15,000",
    "Show me cars costing between $25,000 and $30,000.",
    "Cars over $50k and below $100k are my preference.",
]
for example in examples:
    result = extract_price_range_dynamic(example)
    print(f"Input: {example}")
    print(f"Extracted Price Range: {result}")
    print("-" * 50)

# %%
def transform_nlp_output_to_criteria(nlp_output, price_bins, price_labels):
    """
    Transforms NLP output into the required format for parsed_criteria.

    Parameters:
        nlp_output (dict): Extracted NLP features including MinPrice, MaxPrice, BodyType, etc.
        price_bins (list): Bins for price ranges.
        price_labels (list): Labels for price ranges.

    Returns:
        dict: Formatted parsed_criteria.
    """
    parsed_criteria = {}

    # Handle PriceRange
    min_price = nlp_output.get('MinPrice')
    max_price = nlp_output.get('MaxPrice')

    if min_price is not None or max_price is not None:
        # Assign numerical range for price
        parsed_criteria['MinPrice'] = min_price
        parsed_criteria['MaxPrice'] = max_price

        # Map numerical price range to price category
        if min_price is not None and max_price is not None:
            combined_ranges = [
                price_labels[i]
                for i in range(len(price_bins) - 1)
                if price_bins[i] >= min_price and price_bins[i + 1] <= max_price
            ]
            parsed_criteria['Price_Range'] = combined_ranges
        elif max_price is not None:
            for i in range(len(price_bins) - 1):
                if price_bins[i] <= max_price < price_bins[i + 1]:
                    parsed_criteria['Price_Range'] = price_labels[i]
        elif min_price is not None:
            for i in range(len(price_bins) - 1):
                if price_bins[i] <= min_price < price_bins[i + 1]:
                    parsed_criteria['Price_Range'] = price_labels[i]

    # Handle BodyType
    if 'BodyType' in nlp_output and nlp_output['BodyType']:
        parsed_criteria['Body'] = nlp_output['BodyType']

    # Handle Color
    if 'Color' in nlp_output and nlp_output['Color']:
        parsed_criteria['Ext_Color_Generic'] = nlp_output['Color']

    # Handle other extracted features directly
    additional_keys = ['Miles', 'Fuel_Type', 'Drivetrain', 'PassengerCapacity']
    for key in additional_keys:
        if key in nlp_output:
            parsed_criteria[key] = nlp_output[key]

    return parsed_criteria

# %%
# --- Example NLP Input ---
parsed_criteria = {
    'MinPrice': 20000,               # Extracted minimum price (if provided by NLP)
    'MaxPrice': 50000,               # Extracted maximum price (if provided by NLP)

}

# Apply filtering
filtered_df = filter_vehicles(parsed_criteria)

# Rank and display results or handle no matches
if isinstance(filtered_df, str) or filtered_df.empty:
    print("No matches found. Please update your search criteria.")
else:
    result = rank_vehicles(filtered_df, parsed_criteria, top_n=10)
    if isinstance(result, str):
        print(result)
    else:
        print(result[['Year', 'Make', 'Model', 'SellingPrice', 'Miles', 'Body', 'Ext_Color_Generic', 'Price_Range', 'Miles_Range', 'Score']])

# %%
import pandas as pd

# --- Step 1: Load the Data ---
df = pd.read_csv('vehicles.csv')

# --- Step 2: Eliminate Unnecessary Columns ---
columns_to_drop = ['MRSP', 'Int_Uphalstery', 'Internet_Price']
df = df.drop(columns=columns_to_drop, errors='ignore')

# --- Step 3: Create Price_Range ---
price_bins = [0, 10000, 20000, 30000, 50000, float('inf')]
price_labels = ['$0-$10K', '$10K-$20K', '$20K-$30K', '$30K-$50K', '$50K+']
df['Price_Range'] = pd.cut(df['SellingPrice'], bins=price_bins, labels=price_labels)

# --- Step 4: Create Miles_Range ---
miles_bins = [0, 10000, 30000, 60000, 100000, float('inf')]
miles_labels = ['0-10K', '10K-30K', '30K-60K', '60K-100K', '100K+']
df['Miles_Range'] = pd.cut(df['Miles'], bins=miles_bins, labels=miles_labels)

# --- Step 5: Drop Rows with Missing Ranges ---
df = df.dropna(subset=['Price_Range', 'Miles_Range'])

# --- Step 6: Define the get_combined_ranges Function ---
def get_combined_ranges(user_min, user_max, bins, labels):
    combined_ranges = []
    for i in range(len(bins) - 1):
        bin_min = bins[i]
        bin_max = bins[i + 1]
        if bin_min >= user_min and bin_max <= user_max:
            combined_ranges.append(labels[i])
    return combined_ranges

# --- Step 7: Define the Ranking Algorithm ---
HIERARCHY_WEIGHTS = {
    'Price_Range': 5,
    'Miles_Range': 4,
    'Body': 4,
    'Fuel_Type': 3,
    'Drivetrain': 3,
    'Make': 3,
    'Year': 3,
    'Transmission': 2,
    'PassengerCapacity': 2,
    'Style_Description': 2,
    'Ext_Color_Generic': 2,
    'InteriorColor': 1
}

def calculate_vehicle_score(vehicle, user_criteria):
    score = 0
    for key, value in user_criteria.items():
        if vehicle.get(key) != value:
            #print("HELLO")
            continue
        if pd.notna(vehicle.get(key)) and vehicle.get(key) == value:
            score += HIERARCHY_WEIGHTS.get(key, 0)
    return score

def rank_vehicles(df, user_criteria, top_n=10):
    if df.empty:
        return "No matches found. Please update your search criteria."
    df['Score'] = df.apply(lambda row: calculate_vehicle_score(row, user_criteria), axis=1)
    ranked_vehicles = df.sort_values(by='Score', ascending=False)
    return ranked_vehicles.head(top_n)

def filter_vehicles(parsed_criteria):
    """
    Filter vehicles based on parsed NLP criteria.

    Parameters:
        parsed_criteria (dict): User's criteria extracted from NLP input.

    Returns:
        pd.DataFrame or str: Filtered vehicles DataFrame or a message if no matches are found.
    """
    filtered_df = df.copy()

    # Handle price range dynamically
    min_price = parsed_criteria.get('MinPrice')
    max_price = parsed_criteria.get('MaxPrice')

    if min_price is not None or max_price is not None:
        # Apply SellingPrice filters
        if min_price is not None:
            filtered_df = filtered_df[filtered_df['SellingPrice'] >= min_price]
        if max_price is not None:
            filtered_df = filtered_df[filtered_df['SellingPrice'] <= max_price]

    # Apply other filters based on parsed criteria
    for key, value in parsed_criteria.items():
        if key not in ['MinPrice', 'MaxPrice']:  # Skip MinPrice and MaxPrice
            if key in filtered_df.columns:
                filtered_df = filtered_df[filtered_df[key] == value]

    return filtered_df


# --- Example NLP Input ---
parsed_criteria = {
    'MinPrice': 0,               # Extracted minimum price (if provided by NLP)
    'MaxPrice': 20000,               # Extracted maximum price (if provided by NLP)
    'Body': 'Sport Utility',         # Extracted "SUV"
    'Ext_Color_Generic': 'Red'       # Extracted "Red"
}
# Apply filtering
filtered_df = filter_vehicles(parsed_criteria)
print(f"Length of results {len(filtered_df)}")
print(filtered_df)
# Rank and display results or handle no matches
if isinstance(filtered_df, str) or filtered_df.empty:
    print("No matches found. Please update your search criteria.")
else:
    result = rank_vehicles(filtered_df, parsed_criteria, top_n=10)
    if isinstance(result, str):
        print(result)
    else:
        print(result[['Year', 'Make', 'Model', 'SellingPrice', 'Miles', 'Body', 'Ext_Color_Generic', 'Price_Range', 'Miles_Range', 'Score']])
# Out:
# Length of results 37
#       Type    Stock                VIN  Year           Make  \
# 24    Used  T725034  3J1NRYLYFHZZDJRLH  2020     Land Rover
# 42    Used  X730820  X4PPH8TXJ0XJMP9WC  2015       INFINITI
# 133   Used  I128501  WMZ9NU4VY6YVAC9NU  2018       INFINITI
# 377   Used  U566964  GNCY1VALLUNNTY351  2019     Mitsubishi
# 387   Used  W969043  TYN0GFU8YG6PXRTN2  2021          Mazda
# 451   Used  D529696  LHFF0F9RLU075SJLH  2021     Land Rover
# 460   Used  A319043  10LE65CWWEVW81060  2022        Hyundai
# 493   Used  B187598  DZPS18T33XZ5AVPRY  2024     Mitsubishi
# 534   Used  Y354854  VZKW5P3X77WSP6DGU  2020     Land Rover
# 585   Used  C375359  HGFGKSPE7L6KRRYNB  2021            Kia
# 599   Used  C316063  PK904D3HSFGZVUV78  2017         Nissan
# 651   Used  B203674  VWN4CGYZ1HSRWJESM  2018            GMC
# 725   Used  B060315  LJ7KWSBKYFNPB50JE  2023     Mitsubishi
# 766   Used  I275593  WPKHD37BA8D63VH8S  2022            Kia
# 800   Used  I083283  L271MVZDLBB7UJEEC  2023           Audi
# 886   Used  U427847  C1H10A1590BJUFJXL  2021            Kia
# 894   Used  N631673  M83Y87W4GSJ6YL8T9  2017           Jeep
# 1045  Used  L633141  P9F40B43SKHT5E2PW  2020     Volkswagen
# 1159  Used  W254551  MFMEL7YP5PCRMJNW2  2019     Mitsubishi
# 1169  Used  B129878  ESM4LCKSHUTJ7T21E  2017     Mitsubishi
# 1226  Used  L235809  4GPGJ1E3L2BWWJNL0  2015          Lexus
# 1291  Used  Z589834  EV3TZ6XPRCNGG5H63  2022            Kia
# 1326  Used  E436077  APJ393KKE5ZH5VKCY  2020          Dodge
# 1357  Used  T617936  EATHLK9W0XLRL239T  2019      Chevrolet
# 1364  Used  L358124  2D0MS7LGACKYMCA7K  2018  Mercedes-Benz
# 1428  Used  N869281  HKF1HAGX3E34LG1NW  2022  Mercedes-Benz
# 1458  Used  F409317  1FEG1MAT46CX1EFH8  2022            Kia
# 1482  Used  W825015  GUY6WY408L4XT7B36  2016     Mitsubishi
# 1499  Used  E906750  4ETMWT5HR5WTKWVHL  2023        Hyundai
# 1536  Used  R335212  MSXLYSCY36HNSKBT8  2020       Cadillac
# 1627  Used  C578669  HTFR65426ZV9GTU3X  2017         Nissan
# 1710  Used  L453453  TJ0F701X7PRNYCJL5  2020         Nissan
# 1806  Used  A363623  G32H4SCSUWXPGPPB6  2024           Jeep
# 1821  Used  K976641  YLH36MREKHL7M6ULN  2024         Nissan
# 2011  Used  L956513  NU30NL6K6DKNWWPAD  2021      Chevrolet
# 2080  Used  I705854  2JD2GTJ7MWVKUB6MB  2022        Hyundai
# 2084  Used  O175398  5EUT2DW3ZK7WELZ6A  2018      Chevrolet
#
#                    Model           Body  ModelNumber  Doors  \
# 24    Range Rover Evoque  Sport Utility  LARA-ZR612M      4
# 42                  QX50  Sport Utility  INQX-XJ129W      4
# 133                 QX30  Sport Utility  INQX-KZ533W      4
# 377        Eclipse Cross  Sport Utility  MIEC-PA793Y      4
# 387                 CX-3  Sport Utility  MACX-HJ255H      4
# 451    Range Rover Velar  Sport Utility  LARA-KV232K      4
# 460             Palisade  Sport Utility  HYPA-WA008C      4
# 493        Eclipse Cross  Sport Utility  MIEC-TA405Y      4
# 534    Range Rover Velar  Sport Utility  LARA-MY377U      4
# 585              Sorento  Sport Utility  KISO-DV814B      4
# 599                Rogue  Sport Utility  NIRO-ZJ892L      4
# 651              Terrain  Sport Utility  GMTE-XG782B      4
# 725      Outlander Sport  Sport Utility  MIOU-VD111W      4
# 766             Sportage  Sport Utility  KISP-WN147Z      4
# 800                   Q3  Sport Utility  AUQ3-SR191R      4
# 886              Sorento  Sport Utility  KISO-FS834A      4
# 894              Patriot  Sport Utility  JEPA-PN037P      4
# 1045   Atlas Cross Sport  Sport Utility  VOAT-GP625J      4
# 1159     Outlander Sport  Sport Utility  MIOU-JC223W      4
# 1169     Outlander Sport  Sport Utility  MIOU-WG925N      4
# 1226             NX 200t  Sport Utility  LENX-KY990G      4
# 1291            Sportage  Sport Utility  KISP-WN680T      4
# 1326             Journey  Sport Utility  DOJO-EV175R      4
# 1357              Blazer  Sport Utility  CHBL-FL358B      4
# 1364                 GLC  Sport Utility  MEGL-RC249A      4
# 1428                 GLC  Sport Utility  MEGL-KH345L      4
# 1458                Niro  Sport Utility  KINI-XE209E      4
# 1482           Outlander  Sport Utility  MIOU-ZK928A      4
# 1499                Kona  Sport Utility  HYKO-BG733L      4
# 1536                 XT4  Sport Utility  CAXT-MX264X      4
# 1627               Rogue  Sport Utility  NIRO-XJ418S      4
# 1710               Kicks  Sport Utility  NIKI-CE349R      4
# 1806            Wagoneer  Sport Utility  JEWA-NF770D      4
# 1821              Armada  Sport Utility  NIAR-DT618Z      4
# 2011              Blazer  Sport Utility  CHBL-JG374P      4
# 2080              Tucson  Sport Utility  HYTU-VS206Z      4
# 2084            Traverse  Sport Utility  CHTR-RR308R      4
#
#                           ExteriorColor  ... HighwayMPG  \
# 24                 Firenze Red Metallic  ...       26.0
# 42                      Midnight Garnet  ...       25.0
# 133                        Magnetic Red  ...       33.0
# 377                         Red Diamond  ...       29.0
# 387           Soul Red Crystal Metallic  ...       34.0
# 451                Firenze Red Metallic  ...       26.0
# 460                     Sierra Burgundy  ...       26.0
# 493                         Red Diamond  ...       28.0
# 534                Firenze Red Metallic  ...       24.0
# 585                Passion Red Tintcoat  ...       29.0
# 599                       Palatial Ruby  ...       32.0
# 651                 Red Quartz Tintcoat  ...       30.0
# 725                         Red Diamond  ...       29.0
# 766                           Hyper Red  ...       30.0
# 800                  Tango Red Metallic  ...       28.0
# 886                Passion Red Tintcoat  ...       29.0
# 894   Deep Cherry Red Crystal Pearlcoat  ...       26.0
# 1045                Aurora Red Metallic  ...       22.0
# 1159                 Rally Red Metallic  ...       30.0
# 1169                 Rally Red Metallic  ...       27.0
# 1226                   Matador Red Mica  ...       28.0
# 1291                          Hyper Red  ...       28.0
# 1326               Redline 2 Coat Pearl  ...       25.0
# 1357                 Cajun Red Tintcoat  ...       26.0
# 1364      designo Cardinal Red Metallic  ...       28.0
# 1428   MANUFAKTUR Cardinal Red Metallic  ...       27.0
# 1458                         Runway Red  ...       48.0
# 1482                 Rally Red Metallic  ...       31.0
# 1499                       Ultimate Red  ...       35.0
# 1536                    Garnet Metallic  ...       30.0
# 1627                      Palatial Ruby  ...       32.0
# 1710               Cayenne Red Metallic  ...       36.0
# 1806               Velvet Red Pearlcoat  ...       24.0
# 1821                   Coulis Red Pearl  ...       19.0
# 2011                Cherry Red Tintcoat  ...       27.0
# 2080                        Calypso Red  ...       33.0
# 2084                 Cajun Red Tintcoat  ...       27.0
#
#                 EPAClassification Wheelbase_Code  \
# 24                  Small SUV 4WD          105.6
# 42           Small Station Wagons          110.2
# 133                  Compact Cars          106.3
# 377                 Small SUV 2WD          105.1
# 387                  Compact Cars          101.2
# 451                 Small SUV 4WD          113.1
# 460              Standard SUV 2WD          114.2
# 493                 Small SUV 4WD          105.1
# 534                 Small SUV 4WD          113.1
# 585                 Small SUV 2WD          110.8
# 599                 Small SUV 4WD          106.5
# 651     2WD Sport Utility Vehicle          107.3
# 725                 Small SUV 4WD          105.1
# 766                 Small SUV 2WD          105.1
# 800                 Small SUV 4WD          105.5
# 886                 Small SUV 2WD          110.8
# 894                 Small SUV 2WD          103.7
# 1045                Small SUV 4WD          117.3
# 1159                Small SUV 2WD          105.1
# 1169                Small SUV 4WD          105.1
# 1226                Small SUV 2WD          104.7
# 1291                Small SUV 2WD          105.1
# 1326                Small SUV 2WD          113.8
# 1357       Sport Utility Vehicles          112.7
# 1364                Small SUV 4WD          113.1
# 1428                Small SUV 2WD          113.1
# 1458         Small Station Wagons          106.3
# 1482                Small SUV 2WD          105.1
# 1499                Small SUV 2WD          102.4
# 1536  Small Sport Utility Vehicle          109.4
# 1627                Small SUV 4WD          106.5
# 1710                 Midsize Cars          103.1
# 1806                          NaN          123.0
# 1821                          NaN          121.1
# 2011       Sport Utility Vehicles          112.7
# 2080                Small SUV 2WD          108.5
# 2084       Sport Utility Vehicles          120.9
#
#                         MarketClass  PassengerCapacity    ExtColorHexCode  \
# 24       4WD Sport Utility Vehicles                  5                NaN
# 42                      Small Wagon                  5             1D0708
# 133    4-door Compact Passenger Car                  5             7F0016
# 377      2WD Sport Utility Vehicles                  5                NaN
# 387    4-door Compact Passenger Car                  5             910F18
# 451      4WD Sport Utility Vehicles                  5                NaN
# 460      2WD Sport Utility Vehicles                  7             3A181C
# 493      4WD Sport Utility Vehicles                  5                NaN
# 534      4WD Sport Utility Vehicles                  5                NaN
# 585      2WD Sport Utility Vehicles                  7             A81427
# 599      4WD Sport Utility Vehicles                  5             42141F
# 651      2WD Sport Utility Vehicles                  5             8F1900
# 725      4WD Sport Utility Vehicles                  5                NaN
# 766      2WD Sport Utility Vehicles                  5             721818
# 800      4WD Sport Utility Vehicles                  5                NaN
# 886      2WD Sport Utility Vehicles                  7             A81427
# 894      2WD Sport Utility Vehicles                  5             4C000C
# 1045     4WD Sport Utility Vehicles                  5                NaN
# 1159     2WD Sport Utility Vehicles                  5                NaN
# 1169     4WD Sport Utility Vehicles                  5                NaN
# 1226     2WD Sport Utility Vehicles                  5                NaN
# 1291     2WD Sport Utility Vehicles                  5             721818
# 1326     2WD Sport Utility Vehicles                  7             6A0012
# 1357     2WD Sport Utility Vehicles                  5             8F1900
# 1364     4WD Sport Utility Vehicles                  5                NaN
# 1428     2WD Sport Utility Vehicles                  5                NaN
# 1458                    Small Wagon                  5             94121F
# 1482     2WD Sport Utility Vehicles                  7                NaN
# 1499     2WD Sport Utility Vehicles                  5             B62B31
# 1536     2WD Sport Utility Vehicles                  5             641123
# 1627     4WD Sport Utility Vehicles                  5             42141F
# 1710  4-door Mid-Size Passenger Car                  5             6C1825
# 1806     2WD Sport Utility Vehicles                  7  40000000000000000
# 1821     2WD Sport Utility Vehicles                  7             68161A
# 2011     2WD Sport Utility Vehicles                  5             91040B
# 2080     2WD Sport Utility Vehicles                  5             800F19
# 2084     2WD Sport Utility Vehicles                  7             8F1900
#
#       IntColorHexCode  EngineDisplacementCubicInches  Price_Range  Miles_Range
# 24                NaN                          122.0    $20K-$30K      30K-60K
# 42                NaN                          226.0    $10K-$20K     60K-100K
# 133               NaN                          121.0    $10K-$20K     60K-100K
# 377               NaN                           91.0    $10K-$20K      30K-60K
# 387               NaN                          122.0    $10K-$20K     60K-100K
# 451               NaN                          183.0    $20K-$30K      30K-60K
# 460               NaN                          231.0    $20K-$30K     60K-100K
# 493               NaN                           91.0    $20K-$30K        0-10K
# 534               NaN                          183.0    $20K-$30K      30K-60K
# 585               NaN                          152.0    $20K-$30K      30K-60K
# 599               NaN                          152.0    $10K-$20K     60K-100K
# 651               NaN                            NaN    $10K-$20K      30K-60K
# 725               NaN                          122.0    $10K-$20K      30K-60K
# 766               NaN                          144.0    $10K-$20K      30K-60K
# 800               NaN                          121.0    $20K-$30K      10K-30K
# 886               NaN                          152.0    $20K-$30K        0-10K
# 894               NaN                          122.0    $10K-$20K     60K-100K
# 1045              NaN                          220.0    $20K-$30K      30K-60K
# 1159              NaN                          122.0    $10K-$20K      30K-60K
# 1169              NaN                          144.0    $10K-$20K      30K-60K
# 1226              NaN                          122.0    $10K-$20K      30K-60K
# 1291              NaN                          122.0    $10K-$20K     60K-100K
# 1326              NaN                          144.0    $10K-$20K      30K-60K
# 1357              NaN                            NaN    $20K-$30K      30K-60K
# 1364              NaN                          121.0    $10K-$20K      30K-60K
# 1428              NaN                          121.0    $20K-$30K      10K-30K
# 1458              NaN                           96.0    $10K-$20K      10K-30K
# 1482              NaN                          144.0    $10K-$20K      30K-60K
# 1499              NaN                          122.0    $10K-$20K      30K-60K
# 1536              NaN                            NaN    $20K-$30K      30K-60K
# 1627              NaN                          152.0    $10K-$20K     60K-100K
# 1710              NaN                           98.0    $10K-$20K     60K-100K
# 1806              NaN                          183.0        $50K+      10K-30K
# 1821              NaN                          339.0    $30K-$50K        0-10K
# 2011              NaN                            NaN    $20K-$30K      30K-60K
# 2080              NaN                          152.0    $20K-$30K      30K-60K
# 2084              NaN                            NaN    $10K-$20K      30K-60K
#
# [37 rows x 45 columns]
#       Year           Make               Model  SellingPrice  Miles  \
# 24    2020     Land Rover  Range Rover Evoque         23498  33417
# 1169  2017     Mitsubishi     Outlander Sport         11498  53489
# 1291  2022            Kia            Sportage         18498  77313
# 1326  2020          Dodge             Journey         12498  46112
# 1357  2019      Chevrolet              Blazer         20998  58738
# 1364  2018  Mercedes-Benz                 GLC         18898  35106
# 1428  2022  Mercedes-Benz                 GLC         29998  17892
# 1458  2022            Kia                Niro         18998  18841
# 1482  2016     Mitsubishi           Outlander         12198  53703
# 1499  2023        Hyundai                Kona         16998  31139
#
#                Body Ext_Color_Generic Price_Range Miles_Range  Score
# 24    Sport Utility               Red   $20K-$30K     30K-60K      6
# 1169  Sport Utility               Red   $10K-$20K     30K-60K      6
# 1291  Sport Utility               Red   $10K-$20K    60K-100K      6
# 1326  Sport Utility               Red   $10K-$20K     30K-60K      6
# 1357  Sport Utility               Red   $20K-$30K     30K-60K      6
# 1364  Sport Utility               Red   $10K-$20K     30K-60K      6
# 1428  Sport Utility               Red   $20K-$30K     10K-30K      6
# 1458  Sport Utility               Red   $10K-$20K     10K-30K      6
# 1482  Sport Utility               Red   $10K-$20K     30K-60K      6
# 1499  Sport Utility               Red   $10K-$20K     30K-60K      6

# %%
import openai


import openai
import json
# Set your OpenAI API key
openai.api_key = "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"

# Set your OpenAI API key

def parse_query_to_criteria(prompt):
    """
    Parse user query into structured criteria using GPT.
    """
    system_prompt = """
    You are an intelligent assistant that extracts structured information from customer queries.
    Given a user query, extract relevant car criteria and return it as a dictionary in the following format:
    {
        "Price_Range": "string",
        "Ext_Color_Generic": "string",
        "Miles_Range": "string"
    }
    Use "None" if a criterion is not mentioned in the query.
    """
    
    # Use the correct ChatCompletion method
    response = openai.ChatCompletion.create(
        model="gpt-4",  # Use "gpt-3.5-turbo" if cost is a concern
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": prompt}
        ],
        temperature=0  # For deterministic outputs
    )
    
    # Parse the response content
    output = response['choices'][0]['message']['content']
    try:
        # Convert the response string to a dictionary
        parsed_criteria = json.loads(output)
    except json.JSONDecodeError as e:
        print(f"Error decoding JSON output: {e}")
        parsed_criteria = None

    return parsed_criteria


# Example query
user_query = "Hello, do you guys have any red cars that have driven 10-30 thousand miles and cost 20-30 thousand dollars?"

# Parse the query
parsed_criteria = parse_query_to_criteria(user_query)
print("Parsed Criteria:", parsed_criteria)
# Out:
# ---------------------------------------------------------------------------
# APIRemovedInV1                            Traceback (most recent call last)
# Cell In[53], line 52
#      49 user_query = "Hello, do you guys have any red cars that have driven 10-30 thousand miles and cost 20-30 thousand dollars?"
#      51 # Parse the query
# ---> 52 parsed_criteria = parse_query_to_criteria(user_query)
#      53 print("Parsed Criteria:", parsed_criteria)
#
# Cell In[53], line 27, in parse_query_to_criteria(prompt)
#      15 system_prompt = """
#      16 You are an intelligent assistant that extracts structured information from customer queries.
#      17 Given a user query, extract relevant car criteria and return it as a dictionary in the following format:
#    (...)
#      23 Use "None" if a criterion is not mentioned in the query.
#      24 """
#      26 # Use the correct ChatCompletion method
# ---> 27 response = openai.ChatCompletion.create(
#      28     model="gpt-4",  # Use "gpt-3.5-turbo" if cost is a concern
#      29     messages=[
#      30         {"role": "system", "content": system_prompt},
#      31         {"role": "user", "content": prompt}
#      32     ],
#      33     temperature=0  # For deterministic outputs
#      34 )
#      36 # Parse the response content
#      37 output = response['choices'][0]['message']['content']
#
# File c:\Users\karim\OneDrive\Desktop\CODEJAM14Repo\CodeJam14KKSB\venv\lib\site-packages\openai\lib\_old_api.py:39, in APIRemovedInV1Proxy.__call__(self, *_args, **_kwargs)
#      38 def __call__(self, *_args: Any, **_kwargs: Any) -> Any:
# ---> 39     raise APIRemovedInV1(symbol=self._symbol)
#
# APIRemovedInV1:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742

# %%
print(openai.__version__)
# Out:
# 1.55.0

# %%
import openai

openai.api_key = "your-api-key"

response = openai.Completion.create(
    engine="text-davinci-003",  # Replace with "text-davinci-002" if needed
    prompt="""
    Extract structured criteria from this query:
    'Do you have any red cars under $30,000 with mileage between 10-20K?'

    Format as:
    {
        "Price_Range": "string",
        "Ext_Color_Generic": "string",
        "Miles_Range": "string"
    }
    """,
    max_tokens=100
)

print(response.choices[0].text.strip())
# Out:
# ---------------------------------------------------------------------------
# APIRemovedInV1                            Traceback (most recent call last)
# Cell In[55], line 5
#       1 import openai
#       3 openai.api_key = "your-api-key"
# ----> 5 response = openai.Completion.create(
#       6     engine="text-davinci-003",  # Replace with "text-davinci-002" if needed
#       7     prompt="""
#       8     Extract structured criteria from this query:
#       9     'Do you have any red cars under $30,000 with mileage between 10-20K?'
#      10
#      11     Format as:
#      12     {
#      13         "Price_Range": "string",
#      14         "Ext_Color_Generic": "string",
#      15         "Miles_Range": "string"
#      16     }
#      17     """,
#      18     max_tokens=100
#      19 )
#      21 print(response.choices[0].text.strip())
#
# File c:\Users\karim\OneDrive\Desktop\CODEJAM14Repo\CodeJam14KKSB\venv\lib\site-packages\openai\lib\_old_api.py:39, in APIRemovedInV1Proxy.__call__(self, *_args, **_kwargs)
#      38 def __call__(self, *_args: Any, **_kwargs: Any) -> Any:
# ---> 39     raise APIRemovedInV1(symbol=self._symbol)
#
# APIRemovedInV1:
#
# You tried to access openai.Completion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742

# %%
from transformers import pipeline

# Load a zero-shot classification pipeline
classifier = pipeline("zero-shot-classification", model="facebook/bart-large-mnli")

def parse_query_to_criteria(prompt):
    """
    Parse user query into structured criteria using Hugging Face Transformers.
    """
    # Define potential labels (categories)
    labels = ["Price Range", "Color", "Mileage Range"]

    # Classify the prompt
    result = classifier(prompt, labels, multi_label=True)

    # Map results to a dictionary
    parsed_criteria = {}
    for i, label in enumerate(result["labels"]):
        if result["scores"][i] > 0.5:  # Threshold for relevance
            parsed_criteria[label] = label  # Here, you can refine extraction logic
        else:
            parsed_criteria[label] = None

    return parsed_criteria


# Example usage
user_query = "Do you have any red cars under $30,000 with mileage between 10-20K?"
parsed_criteria = parse_query_to_criteria(user_query)
print("Parsed Criteria:", parsed_criteria)
# Out:
# c:\Users\karim\OneDrive\Desktop\CODEJAM14Repo\CodeJam14KKSB\venv\lib\site-packages\huggingface_hub\file_download.py:139: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\karim\.cache\huggingface\hub\models--facebook--bart-large-mnli. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBartForSequenceClassification: ['model.decoder.version', 'model.encoder.version']
# - This IS expected if you are initializing TFBartForSequenceClassification from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBartForSequenceClassification from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFBartForSequenceClassification were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBartForSequenceClassification for predictions without further training.
# Parsed Criteria: {'Color': 'Color', 'Mileage Range': 'Mileage Range', 'Price Range': 'Price Range'}
